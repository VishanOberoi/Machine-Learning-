# %% [markdown]
# Vishan Oberoi
#
# i033
#
# BTECH AI B2
#
# 18/12/21

# %% [markdown]
# Imports and gathering a basic understanding of the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#Loading the dataset
seed = pd.read_csv("seeds.csv")
seed
# Out:
#       Area  Perimeter  Compactness  ...  Asymmetry.Coeff  Kernel.Groove  Type
# 0    15.26      14.84       0.8710  ...            2.221          5.220     1
# 1    14.88      14.57       0.8811  ...            1.018          4.956     1
# 2    14.29      14.09       0.9050  ...            2.699          4.825     1
# 3    13.84      13.94       0.8955  ...            2.259          4.805     1
# 4    16.14      14.99       0.9034  ...            1.355          5.175     1
# ..     ...        ...          ...  ...              ...            ...   ...
# 194  12.19      13.20       0.8783  ...            3.631          4.870     3
# 195  11.23      12.88       0.8511  ...            4.325          5.003     3
# 196  13.20      13.66       0.8883  ...            8.315          5.056     3
# 197  11.84      13.21       0.8521  ...            3.598          5.044     3
# 198  12.30      13.34       0.8684  ...            5.637          5.063     3
#
# [199 rows x 8 columns]

# %%
seed.head()
# Out:
#     Area  Perimeter  Compactness  ...  Asymmetry.Coeff  Kernel.Groove  Type
# 0  15.26      14.84       0.8710  ...            2.221          5.220     1
# 1  14.88      14.57       0.8811  ...            1.018          4.956     1
# 2  14.29      14.09       0.9050  ...            2.699          4.825     1
# 3  13.84      13.94       0.8955  ...            2.259          4.805     1
# 4  16.14      14.99       0.9034  ...            1.355          5.175     1
#
# [5 rows x 8 columns]

# %%
seed.describe()
# Out:
#              Area   Perimeter  ...  Kernel.Groove        Type
# count  199.000000  199.000000  ...     199.000000  199.000000
# mean    14.918744   14.595829  ...       5.420653    1.994975
# std      2.919976    1.310445  ...       0.492718    0.813382
# min     10.590000   12.410000  ...       4.519000    1.000000
# 25%     12.330000   13.470000  ...       5.046000    1.000000
# 50%     14.430000   14.370000  ...       5.228000    2.000000
# 75%     17.455000   15.805000  ...       5.879000    3.000000
# max     21.180000   17.250000  ...       6.550000    3.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# #Visualisation

# %%
sns.set(rc={'figure.figsize':(10,7)})

# %%
seed["Type"].value_counts(ascending = True)
# Out:
# 3    65
# 1    66
# 2    68
# Name: Type, dtype: int64

# %%
seed.plot(kind = "scatter",x = "Kernel.Length",y = "Kernel.Width")
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
seed.plot(kind = "line",x = "Kernel.Length",y = "Kernel.Width")

# %%
sns.scatterplot(x ='Area' , y ='Perimeter' , data= seed)

# %%
sns.barplot(x ='Type' , y ='Perimeter' , data= seed)

# %%
sns.barplot(x ='Type' , y ='Area' , data= seed)

# %%
sns.jointplot(x ='Perimeter' , y ='Compactness' , data= seed,size = 8,color = )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.jointplot(x ='Perimeter' , y ='Compactness' , kind = "kde", data= seed,size = 8)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2182: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(seed, hue = "Type" ,size = 8).map(plt.scatter, "Perimeter","Area").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.FacetGrid(seed, hue = "Type" ,size = 8).map(plt.scatter, "Compactness","Area").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.boxplot(x ='Type' , y ='Perimeter' , data= seed)

# %% [markdown]
# For my understanding
#
# Boxplot
#
# The box of the boxplot is the interquartile range of the data. Boxplots are good for finding out the outliers of a particular feature. The line in the middle is the median.
#
# Stripplot can be thought of as a complement to violin/ boxplot.

# %%
ax = sns.boxplot(x ='Type' , y ='Compactness' , data= seed)
ax = sns.stripplot(x ='Type' , y ='Compactness' , jitter = True,data= seed)

# %%
sns.violinplot(x ='Type' , y ='Compactness' , data= seed)

# %%
#KDE PLOT

#Checking for normal distribution via shape
sns.FacetGrid(seed,hue = "Type", size = 8).map(sns.kdeplot,"Compactness").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#KDE PLOT

sns.FacetGrid(seed,hue = "Type", size = 8).map(sns.kdeplot,"Area").add_legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#PAIR PLOT
sns.pairplot(seed,hue = "Type",diag_kind = "hist")

# %%
#Andrews curves

from pandas.plotting import andrews_curves
andrews_curves(seed,"Type")

#Overlap of colours is seen
